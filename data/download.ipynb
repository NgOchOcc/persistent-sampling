# %%
from datasets import load_dataset

math500 = load_dataset('HuggingFaceH4/MATH-500')
gsm8k = load_dataset('openai/gsm8k', 'main')
# Out:
# Generating train split: 100%|██████████| 7473/7473 [00:00<00:00, 59320.89 examples/s]
# Generating test split: 100%|██████████| 1319/1319 [00:00<00:00, 208411.64 examples/s]

# %%
math500_test = [item for item in math500['test']]
gsm8k_test = [item for item in gsm8k['test']]

# %%
import json

json.dump(math500_test, open('math500.json', 'w'), indent=4)
json.dump(gsm8k_test, open('gsm8k.json', 'w'), indent=4)
